# %%
# !pip install lmdb
# Out:
# Collecting lmdb
#   Downloading lmdb-1.3.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (305 kB)
#      |████████████████████████████████| 305 kB 10.7 MB/s eta 0:00:01
# Installing collected packages: lmdb
# Successfully installed lmdb-1.3.0

# %%
import openslide
from matplotlib.colors import ListedColormap
from skimage import color
import skimage.morphology  as skmp
from histolab.slide import Slide
import numpy as np
from PIL import Image
import tifffile
from histolab.filters.image_filters import (
    ApplyMaskImage,
    Compose,
    OtsuThreshold,
    RgbToGrayscale,GreenPenFilter,BluePenFilter
)
from histolab.filters.morphological_filters import BinaryDilation,BinaryErosion,BinaryClosing,BinaryOpening,RemoveSmallObjects,RemoveSmallHoles
import cv2
import glob
import time
import lmdb

# %%
def composed_filters(image_rgb):
    filters = Compose(
        [
            RgbToGrayscale(),
            OtsuThreshold(),
#             BinaryDilation(),
#             BinaryErosion(),
            BinaryClosing(),
            RemoveSmallHoles(),
#             BinaryClosing(),
#             BinaryDilation(),
            RemoveSmallObjects(),
            ApplyMaskImage(image_rgb),
            BluePenFilter(),
            GreenPenFilter(),

        ]
    )
    return filters(image_rgb)



class TileGenerator:
    def __init__(
        self,
        slide_path,
        tile_size,
        overlap=0
    ):
        """
        Create a DeepZoomGenerator wrapping an OpenSlide object.
        :param slide_path: location for the slide
        :param slide_id: id of current slide (e.g., slide name)
        :param tile_size: the width and height of a single tile.  For best viewer
                          performance, tile_size + 2 * overlap should be a power
                          of two.
        :param overlap: Overlapping size (only used when tiles are extracted from the grid)
        """
        self.slide = openslide.OpenSlide(slide_path)
        self.slide_path = slide_path
        self.slide_id = slide_path.split("/")[-1].split(".")[0]
        self.tile_size = tile_size
        self.overlap = int(overlap)
        self.extraction_tile_size = int(self.tile_size)
        self.extraction_overlap = int(self.overlap)
        
        #extract thumbnail and mask non-tissue
        thumb_down_rate = 8
        size = np.array(self.slide.level_dimensions)[0] // thumm_down_rate
        self.thumbnail = np.array(slide.get_thumbnail([size[0], size[1]]).convert('RGB'))
        self.thumbnail_masked = np.array(composed_filters(Image.fromarray(self.thumbnail)))
        
    def get_tile_locations(self, tissue_thred):
        """
        Generate tiles locations at the highest resolution from the grid
        :param tissue_thred: tissue threshold (i.e., tile contains tissue region greater than thred)
        :return:
        """
        # Get the downsample rate from level 0 to mask level
        downsample_rate = self.slide.level_dimensions[0][0] / self.thumbnail_masked.shape[1]
        tile_size = self.tile_size 
        overlap = self.overlap
        interval = tile_size - overlap
        # Calculate the tile size to be used at the mask level
        mask_tile_size = int(tile_size / downsample_rate)
        highest_dimension = self.slide.level_dimensions[0]
        lowest_dimension = self.thumbnail_masked.shape[:2]
        counter = 0
        location_tracker = {}
        for i in range(0, int(highest_dimension[0]), int(interval)):
            for j in range(0, int(highest_dimension[1]), int(interval)):
                mask_i = i / downsample_rate
                mask_j = j / downsample_rate
                if (
                    (mask_i + mask_tile_size) < lowest_dimension[1]
                    and (mask_j + mask_tile_size) < lowest_dimension[0]
                    and (i + tile_size < highest_dimension[0])
                    and (j + tile_size < highest_dimension[1])
                ):
                    mask_tile = self.thumbnail_masked[
                        int(mask_j) : int(mask_j + mask_tile_size),
                        int(mask_i) : int(mask_i + mask_tile_size),
                    ]
                    if (
                        float(np.sum(np.array(mask_tile > 0).astype(np.uint8))) / float(mask_tile_size ** 2)
                    ) >= tissue_thred:
                        location_tracker[counter] = (
                            int(i),
                            int(j),
                        )
                        counter += 1

        return counter, location_tracker

# %%
### function to exctract tile given its location from slide
def generate_tile(slide, tile_size, location, normalizer):
    orig_tile = slide.read_region((location[0], location[1]), 0, (tile_size, tile_size))
    orig_tile = np.asarray(orig_tile.convert('RGB'))
    return orig_tile
    return orig_tile

# %%
### generate list of tiles locations for given slide_id
t1 = time.time()
slide_id = '00c058_0'
slide_path = '/data/neuro/stroke/kaggle_strip_ai/train/{0}.tif'.format(slide_id)
slide = openslide.OpenSlide(slide_path)

slide_name = slide_path.split('/')[::-1][0].split('.')[0]
tile_size = 256
overlap = 0
tissue_thred = 0.5 

tile_generator = TileGenerator(
    slide_path,
    tile_size,
    overlap
)
counter, location_tracker = tile_generator.get_tile_locations(
    tissue_thred=tissue_thred
)
location_dict: dict = {}
location_dict[slide_name] = location_tracker
print('finished extracting tile location', (time.time() - t1))
# Out:
# finished extracting tile location 64.12947058677673

# %%
location_dict
# Out:
# {'029c68_0': {0: (4608, 13568),
#   1: (4608, 13824),
#   2: (4608, 14080),
#   3: (4864, 11776),
#   4: (4864, 12544),
#   5: (4864, 12800),
#   6: (4864, 13056),
#   7: (4864, 13312),
#   8: (4864, 13568),
#   9: (4864, 13824),
#   10: (4864, 14080),
#   11: (5120, 11520),
#   12: (5120, 11776),
#   13: (5120, 12032),
#   14: (5120, 12544),
#   15: (5120, 12800),
#   16: (5120, 13056),
#   17: (5120, 13312),
#   18: (5120, 13568),
#   19: (5120, 13824),
#   20: (5120, 14080),
#   21: (5120, 14336),
#   22: (5376, 11264),
#   23: (5376, 11520),
#   24: (5376, 11776),
#   25: (5376, 12800),
#   26: (5376, 13056),
#   27: (5376, 13312),
#   28: (5376, 13568),
#   29: (5376, 13824),
#   30: (5376, 14080),
#   31: (5376, 14336),
#   32: (5376, 14592),
#   33: (5376, 14848),
#   34: (5376, 15104),
#   35: (5376, 15360),
#   36: (5376, 15616),
#   37: (5632, 11008),
#   38: (5632, 11264),
#   39: (5632, 11520),
#   40: (5632, 11776),
#   41: (5632, 13568),
#   42: (5632, 13824),
#   43: (5632, 14080),
#   44: (5632, 14592),
#   45: (5632, 14848),
#   46: (5632, 15104),
#   47: (5632, 15360),
#   48: (5632, 15616),
#   49: (5632, 15872),
#   50: (5632, 21248),
#   51: (5632, 21504),
#   52: (5632, 21760),
#   53: (5888, 11008),
#   54: (5888, 11264),
#   55: (5888, 11520),
#   56: (5888, 11776),
#   57: (5888, 12032),
#   58: (5888, 14336),
#   59: (5888, 14592),
#   60: (5888, 14848),
#   61: (5888, 15104),
#   62: (5888, 15360),
#   63: (5888, 15616),
#   64: (5888, 15872),
#   65: (5888, 20736),
#   66: (5888, 20992),
#   67: (5888, 21248),
#   68: (5888, 21504),
#   69: (5888, 21760),
#   70: (5888, 22016),
#   71: (5888, 22272),
#   72: (5888, 22528),
#   73: (5888, 22784),
#   911: (10752, 8192),
#   912: (10752, 8448),
#   913: (10752, 8704),
#   914: (10752, 8960),
#   915: (10752, 9216),
#   916: (10752, 9472),
#   917: (10752, 9728),
#   918: (10752, 9984),
#   919: (10752, 10240),
#   920: (10752, 10496),
#   921: (10752, 10752),
#   922: (10752, 11008),
#   923: (10752, 11264),
#   924: (10752, 11520),
#   925: (10752, 11776),
#   926: (10752, 12288),
#   927: (10752, 12544),
#   928: (10752, 12800),
#   929: (10752, 13056),
#   930: (10752, 13312),
#   931: (10752, 15872),
#   932: (10752, 16128),
#   933: (10752, 16384),
#   934: (10752, 16640),
#   935: (10752, 16896),
#   936: (10752, 17152),
#   937: (10752, 17408),
#   938: (10752, 17664),
#   939: (10752, 17920),
#   940: (10752, 18176),
#   941: (10752, 18432),
#   942: (10752, 18688),
#   943: (10752, 22528),
#   944: (10752, 24320),
#   945: (10752, 24576),
#   946: (11008, 6912),
#   947: (11008, 7168),
#   948: (11008, 7680),
#   949: (11008, 7936),
#   950: (11008, 8192),
#   951: (11008, 8448),
#   952: (11008, 8704),
#   953: (11008, 8960),
#   954: (11008, 9216),
#   955: (11008, 9472),
#   956: (11008, 9728),
#   957: (11008, 9984),
#   958: (11008, 10240),
#   959: (11008, 10496),
#   960: (11008, 10752),
#   961: (11008, 11008),
#   962: (11008, 11264),
#   963: (11008, 11520),
#   964: (11008, 11776),
#   965: (11008, 12032),
#   966: (11008, 12288),
#   967: (11008, 12544),
#   968: (11008, 12800),
#   969: (11008, 13056),
#   970: (11008, 15872),
#   971: (11008, 16128),
#   972: (11008, 16384),
#   973: (11008, 16896),
#   974: (11008, 17152),
#   975: (11008, 17408),
#   976: (11008, 17664),
#   977: (11008, 17920),
#   978: (11008, 18176),
#   979: (11008, 18432),
#   980: (11264, 8192),
#   981: (11264, 8448),
#   982: (11264, 8704),
#   983: (11264, 8960),
#   984: (11264, 9216),
#   985: (11264, 9472),
#   986: (11264, 9728),
#   987: (11264, 9984),
#   988: (11264, 10240),
#   989: (11264, 10496),
#   990: (11264, 10752),
#   991: (11264, 11008),
#   992: (11264, 11264),
#   993: (11264, 11520),
#   994: (11264, 11776),
#   995: (11264, 12032),
#   996: (11264, 12288),
#   997: (11264, 12544),
#   998: (11264, 12800),
#   999: (11264, 13056),
#   ...}}

# %%
### find out how many tiles were exctracted
counter = len(location_dict[slide_id].keys())
counter
# Out:
# 2439

# %%
### extract all tiles and save to orig_tiles array
t1 = time.time()
orig_tiles = np.zeros((counter, tile_size, tile_size, 3), dtype=np.uint8)
for tile_id in range(counter):
    cur_loc = location_dict['00c058_0'][tile_id]
    orig_tile = generate_tile(slide, tile_size, [int(cur_loc[0]), int(cur_loc[1])], normalizer=False)
    orig_tiles[tile_id] =  orig_tile
print('finished extracting tiles to array', (time.time() - t1))
# Out:
# finished extracting tiles to array 9.637192487716675

# %% [markdown]
# ### lmdb database array writing

# %%
import lmdb

# %%
lmdb_loc = '/data/eredekop/stroke_kaggle/processed/lmdb'
env = lmdb.open("%s" % lmdb_loc, map_size=6e+13)
# Out:
# /tmp/ipykernel_3646/2938750689.py:2: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   env = lmdb.open("%s" % lmdb_loc, map_size=6e+13)

# %%
with env.begin(write=True) as txn:
    write_start = time.time()
    txn.put(str(slide_id).encode(), orig_tiles.astype(np.uint8).tobytes())
    # put location
#     txn_locs.put(("%s_loc" % str(data['slide_id'])).encode(), data['locations'].astype(np.int64).tobytes())
print("Finish writing time: %f" % (time.time() - write_start))
# Out:
# Finish writing time: 1.654622

# %%
### always need to close environment
env.close()

# %% [markdown]
# ### lmdb database array reading

# %%
env = lmdb.open("%s" % (lmdb_loc), max_readers=3, readonly=True,
                             lock=False, readahead=False, meminit=False)

# %%
with env.begin(write=False) as txn:
    tilebuf = txn.get(str(slide_id).encode())
    tilebuf = np.frombuffer(tilebuf, dtype=np.uint8)
    tilebuf = tilebuf.reshape(-1, tile_size, tile_size, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_20927/917029310.py in <module>
#       1 with env.begin(write=False) as txn:
#       2     tilebuf = txn.get(str('029c68_0').encode())
# ----> 3     tilebuf = np.frombuffer(tilebuf, dtype=np.uint8)
#       4     tilebuf = tilebuf.reshape(-1, tile_size, tile_size, 3)
#
# TypeError: a bytes-like object is required, not 'NoneType'

# %%
tilebuf.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_20927/867907392.py in <module>
# ----> 1 tilebuf.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
### always need to close environment
env.close()

# %% [markdown]
# ### database for all slides

# %%
lmdb_loc = '/data/eredekop/stroke_kaggle/processed/lmdb'
env = lmdb.open("%s" % lmdb_loc, map_size=6e+13)
# Out:
# /tmp/ipykernel_20927/2938750689.py:2: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   env = lmdb.open("%s" % lmdb_loc, map_size=6e+13)

# %%
all_files = glob.glob('/data/neuro/stroke/kaggle_strip_ai/train/*.tif')
all_files
# Out:
# ['/data/neuro/stroke/kaggle_strip_ai/train/006388_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/008e5c_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/00c058_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/01adc5_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/026c97_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/028989_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/029c68_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/032f10_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0372b0_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/037300_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/03d1ec_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/03e6b7_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0415c3_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/04439c_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/045eb0_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0468a8_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0468a8_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/049194_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/049194_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/04f7a4_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/055f6a_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/05a1ec_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/062387_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/070fe0_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/08d3d8_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/09644e_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/09644e_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/09644e_2.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/09644e_3.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/09644e_4.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/098f15_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0a3ad1_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0a47c9_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0aaeb3_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0aff58_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0b25f8_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0b7871_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0b7871_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0b7cc8_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0ba49d_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0bd414_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0bddf9_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0c60b8_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0cc0bc_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0d4164_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0d533f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0d718a_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0d93ce_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0df5f8_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0e4dac_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0e696a_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0e696a_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0ed87f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0ed87f_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0ee750_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0ee750_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0f2961_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0fcfe9_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0ff6fc_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/0ff890_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/112b6e_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/112b6e_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/113bb3_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/129102_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1295bb_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/12c8c9_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/13f372_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/140d1a_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/14d2fa_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/15aab4_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/15de51_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/162cad_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1764ff_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/194e3f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/19b036_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/19b036_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/19dd95_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1a2e9e_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1b86c5_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1bbcba_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1d0518_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1d1bf0_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1d5335_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1d6d4f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1db82d_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1db82d_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1ec69e_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1ef6da_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1f018f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1f9d4f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1f9d4f_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1fe0c4_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/1ffc5d_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/205025_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/20914b_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/20d5cf_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/214cfa_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/214cfa_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/21726e_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/217b27_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/21b106_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/2244d2_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/2268cf_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/2394f6_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/23b492_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/23d2c1_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/23d2c1_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/23d2c1_2.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/2446b8_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/244aeb_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/244aeb_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/244aeb_2.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/245758_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/24f8f5_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train
_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/dbd64b_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/dbecb3_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/dc8f86_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/dc8f86_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/dca376_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/dca3b1_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/dd05a2_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/dd6316_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/de9e4c_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/deec71_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/defd00_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/df2c0d_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/df4c9c_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/df543d_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/df543d_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/dfd99d_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e0b829_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e0cfd5_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e10f49_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e10fdb_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e251ff_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e26a04_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e26a04_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e316dd_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e316dd_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e3a230_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e3a24f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e3e850_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e3f976_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e5bd0b_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e5f672_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e60ca1_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e65811_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e6764f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e6ceb4_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e6ceb4_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e72352_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e732f6_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e732f6_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e7bec8_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e7d583_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e8dceb_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e96bd3_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e9c181_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/e9c181_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ea2aad_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/eb21f0_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/eb6733_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ebb225_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ebce5d_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ec3098_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ed5006_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/edc9a4_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/eebf8d_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/eebf8d_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/eebf8d_2.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ef0c95_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ef1b15_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ef68ba_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f05449_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f115aa_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f1f952_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f1f952_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f1f952_2.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f27c51_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f2aba9_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f2c002_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f322da_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f3e9f6_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f3e9f6_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f40c69_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f40c69_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f40c69_2.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f40c69_3.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f4287c_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f4c9ff_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f4d8f8_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f56138_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f57f2e_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f58fcb_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f5ce23_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f75146_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f75146_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f7f1bc_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f7fb11_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f83bf0_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f8712b_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f94fb1_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f9569b_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f95d8b_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f95d8b_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f9c105_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f9fc6b_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/f9fc6b_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fa0080_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fa9050_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fa9747_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fad610_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fb5f7e_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fb5f7e_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fb8bf8_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fbdcde_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fbdcde_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fbf2eb_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fd3079_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fd368e_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fd418f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fd684f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fd7c5b_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fdce0f_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fdce0f_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fdce0f_2.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fde9ba_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fdf998_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fdf998_1.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fe0cca_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fe9645_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/fe9bec_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ff14e0_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ffec5c_0.tif',
#  '/data/neuro/stroke/kaggle_strip_ai/train/ffec5c_1.tif']

# %%
with env.begin(write=True) as txn:
    for i in range(len(all_files)):
        t1 = time.time()
        slide_path = all_files[i]
        slide_id = slide_path.split('/')[::-1][0].split('.')[0]
        slide = openslide.OpenSlide(slide_path)
        
        tile_size = 256
        overlap = 0
        tissue_thred = 0.5 

        tile_generator = TileGenerator(
            slide_path,
            tile_size,
            overlap
        )
        counter, location_tracker = tile_generator.get_tile_locations(
            tissue_thred=tissue_thred
        )
        location_dict: dict = {}
        location_dict[slide_id] = location_tracker
        orig_tiles = np.zeros((counter, tile_size, tile_size, 3), dtype=np.uint8)
        for tile_id in range(counter):
            cur_loc = location_dict[slide_id][tile_id]
            orig_tile = generate_tile(slide, tile_size, [int(cur_loc[0]), int(cur_loc[1])], normalizer=False)
            orig_tiles[tile_id] =  orig_tile
        txn.put(str(slide_id).encode(), orig_tiles.astype(np.uint8).tobytes())
        print('Finished: ', i, slide_id, time.time() - t1)
# Out:
# Finished:  0 006388_0 381.42585134506226
# Finished:  1 008e5c_0 26.912149906158447
# Finished:  2 00c058_0 82.83898758888245
# Finished:  3 01adc5_0 228.55203580856323
# Finished:  4 026c97_0 13.725768566131592
# Finished:  5 028989_0 443.6755635738373
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipykernel_20927/3970790506.py in <module>
#      25             orig_tile = generate_tile(slide, tile_size, [int(cur_loc[0]), int(cur_loc[1])], normalizer=False)
#      26             orig_tiles[tile_id] =  orig_tile
# ---> 27         txn.put(str(slide_id).encode(), orig_tiles.astype(np.uint8).tobytes())
#      28         print('Finished: ', i, slide_id, time.time() - t1)
#
# Error: mdb_put: Input/output error

# %%
slide_id, orig_tiles.shape
# Out:
# ('029c68_0', (2649, 256, 256, 3))

# %%
env.close()

# %%
pqueue = Queue()
start_idx = 0
for i in range(opts.num_ps-1):
    end_idx = start_idx + batch_size
    reader_p = Process(target=generate_helper, args=(pqueue, opts,
                                                     slides_to_process[start_idx: end_idx]))
    reader_p.start()
    reader_processes.append(reader_p)
    start_idx = end_idx
# Ensure all slides are processed by processes.
reader_p = Process(target=generate_helper, args=(pqueue, opts, slides_to_process[start_idx: len(slides_to_process)]))
reader_p.start()
reader_processes.append(reader_p)

counter, ihc_counter, num_done = 0, 0, 0
batches = []

while True:
    # Block if necessary until an item is available.
    data = pqueue.get()
    print("Queue len: %d" % pqueue.qsize())
    # Done indicates job on one process is finished.
    if data == "Done":
        num_done += 1
        print("One part is done!")
        if num_done == opts.num_ps:
            break
    elif data == "ihc":
        counter += 1
        ihc_counter += 1
    else:
        batches.append(data)
    # Write a batch of data.
    if len(batches) == opts.write_batch_size:
        counter = write_batch_data(env_5x, env_10x, env_locs, batches, len(slides_to_process), counter)
# Write the rest data.
if len(batches) > 0:
    counter = write_batch_data(env_5x, env_10x, env_locs, batches, len(slides_to_process), counter)
for process in reader_processes:
    process.join()
assert counter == len(slides_to_process), "%d processed slides, %d slides to be processed" \
                                          % (counter, len(slides_to_process))
print("Number of ihc slides: %d" % ihc_counter)

# %%
def generate_helper(pqueue, opts, slides_to_process):
    tile_normalizer = reinhard_bg.ReinhardNormalizer()
    # use the pre-computed LAB mean and std values
    tile_normalizer.fit(None)
    counter = 0
    for slide_info in slides_to_process:
        slide_id = slide_info['slide_id']
        slide_loc = opts.slide_loc
        if not os.path.isfile("%s/%s.svs" % (opts.slide_loc, str(slide_id))):
            slide_loc = opts.slide_archive_loc
        tile_generator = generate_grid.TileGeneratorGrid(slide_loc, slide_id, opts.tile_size_10x, opts.mag,
                                                         opts.overlap, check_ihc=True, verbose=opts.verbose)
        if tile_generator.ihc is True:
            counter += 1
            pqueue.put("ihc")
            continue
        _, norm_tiles_high, locations, _ = tile_generator.gen_and_extract_tiles(tile_normalizer, opts.ts_thres)
        if len(norm_tiles_high) == 0:
            counter += 1
            pqueue.put("ihc")
            continue
        im_size_high = norm_tiles_high[0].shape[0]
        norm_tiles_low = np.zeros((len(norm_tiles_high), im_size_high // 2, im_size_high // 2, 3), dtype=np.uint8)
        for tile_id in range(len(norm_tiles_high)):
            norm_tile_high = Image.fromarray(norm_tiles_high[tile_id].astype(np.uint8))
            norm_tile_low = norm_tile_high.resize((im_size_high // 2, im_size_high // 2), Image.ANTIALIAS)
            norm_tiles_low[tile_id, :, :, :] = norm_tile_low

        data = {
            "slide_id": slide_id,
            "norm_tiles_10x": norm_tiles_high,
            "norm_tiles_5x": norm_tiles_low,
            "locations": locations
        }
        pqueue.put(data)
        counter += 1
        print("Put tiled slide [%s] on to queue: [%d]/[%d]" % (slide_id, counter, len(slides_to_process)))
    pqueue.put('Done')
